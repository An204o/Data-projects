# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("grocery_sales.csv")
df.head()
# Out:
#   storeID  product  quantity  revenue
# 0       A   Apples      1811   9300.6
# 1       A  Bananas      1003   3375.2
# 2       A  Oranges      1604   8528.5
# 3       B   Apples      1785   9181.0
# 4       B  Bananas       944   3680.2

# %%
df.shape
# Out:
# (78, 4)

# %%
df.describe(exclude = "number")
# Out:
#        storeID product
# count       78      78
# unique      26       3
# top          A  Apples
# freq         3      26

# %%
#Feature selection
df.drop('storeID', axis = 1)
# Out:
#     product  quantity  revenue
# 0    Apples      1811   9300.6
# 1   Bananas      1003   3375.2
# 2   Oranges      1604   8528.5
# 3    Apples      1785   9181.0
# 4   Bananas       944   3680.2
# ..      ...       ...      ...
# 73  Bananas       902   3169.8
# 74  Oranges      1441   6856.1
# 75   Apples      1441   7209.0
# 76  Bananas      1199   4440.5
# 77  Oranges       973   3990.4
#
# [78 rows x 3 columns]

# %%
# Out:
#   storeID  product  quantity  revenue
# 0       A   Apples      1811   9300.6
# 1       A  Bananas      1003   3375.2
# 2       A  Oranges      1604   8528.5
# 3       B   Apples      1785   9181.0
# 4       B  Bananas       944   3680.2

# %%
sns.pairplot(df)
