# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CrossEntropyLoss
input = torch.tensor([[0.5, 1, 3.5, 4.4, 8, 9]])

# %%
model = nn.Sequential(nn.Linear(6, 4), nn.Linear(4, 2), nn.Linear(2, 2), nn.Sigmoid())
output = model(input)
print(output)
# Out:
# tensor([[0.6771, 0.4152]], grad_fn=<SigmoidBackward0>)

# %%
L0 = F.one_hot(torch.tensor(0),num_classes=2)
L1 = F.one_hot(torch.tensor(1),num_classes=2)

# %%
import torch
import torch.nn.functional as F
from torch.nn import BCEWithLogitsLoss

output = torch.tensor([[0.0988, 0.1997]])

# One-hot encoded target
one_hot_target = torch.tensor([[1, 0]])  # Shape: (1, 2)

# Define the loss function (BCEWithLogitsLoss works with one-hot encoded labels)
criterion = CrossEntropyLoss()
# Compute the loss
loss = criterion(output.float(), one_hot_target.float())
print(loss)
# Out:
# tensor(0.7449)

# %%
# Define the loss function
criterion = CrossEntropyLoss()

# Compute the loss
loss = criterion(output.float(), one_hot_target.float())
print(loss)
# Out:
# tensor(0.7449)

# %%
import torch.optim as optim
optimizer = optim.SGD(model.parameters(), lr = 0.001)
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %% [markdown]
# DataLoader
